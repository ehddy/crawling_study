# %%
import os
import sys
import requests
import json
client_id = "7r5nulu59a"
client_secret = "DcWCKwUxqUEOqPSGEzu7wdFboIqH8h9tRE7LFPvc"
url = "https://naveropenapi.apigw.ntruss.com/vision/v1/face" # 얼굴감지
# url = "https://naveropenapi.apigw.ntruss.com/vision/v1/celebrity" # 유명인 얼굴인식
files = {'image': open('아이유.jpeg', 'rb')}
headers = {'X-NCP-APIGW-API-KEY-ID': client_id, 'X-NCP-APIGW-API-KEY': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code


if(rescode==200):
    # json 형태 
    print (response.text)
    # json을 텍스트 형식을 변환 
    data = json.loads(response.text)
    faceCount = data['info']['faceCount']
    print()
    print("감지된 얼굴 수는 {}입니다.".format(faceCount))
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":183,"height":275},"faceCount":1},"faces":[{"roi":{"x":47,"y":62,"width":93,"height":93},"landmark":{"leftEye":{"x":65,"y":85},"rightEye":{"x":113,"y":81},"nose":{"x":92,"y":114},"leftMouth":{"x":79,"y":139},"rightMouth":{"x":110,"y":138}},"gender":{"value":"female","confidence":0.998847},"age":{"value":"21~25","confidence":1.0},"emotion":{"value":"neutral","confidence":0.999976},"pose":{"value":"frontal_face","confidence":0.999534}}]}
#
# 감지된 얼굴 수는 1입니다.

# %% [markdown]
# ![%E1%84%8B%E1%85%A1%E1%84%8B%E1%85%B5%E1%84%8B%E1%85%B2.jpeg](attachment:%E1%84%8B%E1%85%A1%E1%84%8B%E1%85%B5%E1%84%8B%E1%85%B2.jpeg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 네이버 클라우드 플랫폼에서 회원가입하고 신청해야함(api 헤더가 다르니 주의: https://api.ncloud-docs.com/docs/ai-naver-clovafacerecognition)

# %% [markdown]
# 얼굴감지 응답바디 :  https://api.ncloud-docs.com/docs/ai-naver-clovafacerecognition-face
# 유명인 응답바디 : https://api.ncloud-docs.com/docs/ai-naver-clovafacerecognition-celebrity

# %% [markdown]
# ![image.png](attachment:image.png)
