# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs 
search_title = input('검색 제목을 입력해주세요: ')
driver = webdriver.Chrome('/Users/dongyokim/main/jupyter/chromedriver/chromedriver')
driver.get("https://www.youtube.com/results?search_query={}".format(search_title))
# Out:
# 검색 제목을 입력해주세요: 아이유
# /var/folders/7d/bm3zqtjx7xsb__yxj254h7kh0000gn/T/ipykernel_81688/241221729.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/dongyokim/main/jupyter/chromedriver/chromedriver')

# %% [markdown]
# Keys.ARROW_DOWN , Keys.ARROW_LEFT , Keys.ARROW_RIGHT
# Keys.ARROW_UP , Keys.BACK_SPACE , Keys.CONTROL
# Keys.ALT , Keys.DELETE , Keys.ENTER , Keys.SHIFT
# Keys.SPACE , Keys.TAB , Keys.EQUALS , Keys.ESCAPE
# Keys.HOME , Keys.INSERT , PgUp Key  Keys.PAGE_UP
# Keys.PAGE_DOWN , Keys.F1 , Keys.F2 , Keys.F3 , Keys.F4
# Keys.F5 , Keys.F6 , Keys.F7 , Keys.F8 , Keys.F9 , Keys.F10
# gKeys.F11 , Keys.F12

# %%
html = driver.page_source
soup = bs(html, 'html.parser')

# %%
content_lists = soup.find('div', {'id':'contents'})
content_boxs = content_lists.find_all('ytd-video-renderer')

# %%
youtube_list = []
for i, box in enumerate(content_boxs):
    title = box.select_one('#video-title > yt-formatted-string').text
    view_count = box.select_one('#metadata-line > span:nth-child(1)').text.replace('조회수', '')
    past_days = box.select_one('#metadata-line > span:nth-child(2)').text
    channel_name = box.select_one('#text > a').text
    link = 'https://www.youtube.com/' + box.select_one('#video-title')['href']
    
    
    print("===== {}번 box =====".format(i+1))
    print('영상제목 :', title)
    print('조회수 :', view_count)
    print('영상 게시일(현재날짜기준) :', past_days)
    print('채널명 :', channel_name)
    print('영상 링크 :', link)
    print('===================', end='\n\n')
    time.sleep(0.5)
    
    youtube_list.append([title, view_count, past_days, channel_name, link])

driver.quit()
# Out:
# ===== 1번 box =====
# 영상제목 : 아이유 노래모음 30곡 (가사포함) | IU Playlist 30 Songs (Korean Lyrics)
# 조회수 :  466만회
# 영상 게시일(현재날짜기준) : 9개월 전
# 채널명 : 밤공원 PLAYLIST
# 영상 링크 : https://www.youtube.com//watch?v=YlY2CJaErdE
# ===================
#
# ===== 2번 box =====
# 영상제목 : 아이유가 직장상사면 벌어지는 일
# 조회수 :  9.3천회
# 영상 게시일(현재날짜기준) : 4시간 전
# 채널명 : 아이유 에델바이스
# 영상 링크 : https://www.youtube.com//shorts/cIqXZlrWegA
# ===================
#
# ===== 3번 box =====
# 영상제목 : 아이유(IU)의 킬링보이스를 라이브로! - 하루 끝, 너의 의미, 스물셋, 밤편지, 팔레트, 가을 아침, 삐삐, Blueming, 에잇, Coin, 라일락 ㅣ 딩고뮤직
# 조회수 :  4805만회
# 영상 게시일(현재날짜기준) : 1년 전
# 채널명 : 딩고 뮤직 / dingo music
# 영상 링크 : https://www.youtube.com//watch?v=wDfqXR_5yyQ
# ===================
#
# ===== 4번 box =====
# 영상제목 : [아이유의 팔레트🎨] j-hope In The Palette (With j-hope) Ep.14
# 조회수 :  655만회
# 영상 게시일(현재날짜기준) : 5일 전
# 채널명 : 이지금 [IU Official]
# 영상 링크 : https://www.youtube.com//watch?v=nw1qH6vR-8o
# ===================
#
# ===== 5번 box =====
# 영상제목 : 아이유 노래 모음 BEST 50곡, (IU song collection 50 Playlist ) 보고듣는 소울뮤직TV
# 조회수 :  41만회
# 영상 게시일(현재날짜기준) : 8개월 전
# 채널명 : 소울뮤직TV
# 영상 링크 : https://www.youtube.com//watch?v=FLXFbDudeBs
# ===================
#
# ===== 6번 box =====
# 영상제목 : [IU] '내 손을 잡아(Hold My Hand)' Live Clip (2019 IU Tour Concert 'Love, poem')
# 조회수 :  4748만회
# 영상 게시일(현재날짜기준) : 1년 전
# 채널명 : 이지금 [IU Official]
# 영상 링크 : https://www.youtube.com//watch?v=3iM_06QeZi8
# ===================
#
# ===== 7번 box =====
# 영상제목 : [MV] IU(아이유) _ Celebrity
# 조회수 :  1.3억회
# 영상 게시일(현재날짜기준) : 1년 전
# 채널명 : 1theK (원더케이)
# 영상 링크 : https://www.youtube.com//watch?v=0-q1KafFCLU
# ===================
#
# ===== 8번 box =====
# 영상제목 : [ Lyrics ] 아이유 노래모음 30곡 가사포함 IU Playlist 30 Songs Korean
# 조회수 :  3만회
# 영상 게시일(현재날짜기준) : 2개월 전
# 채널명 : 반짝이는 별
# 영상 링크 : https://www.youtube.com//watch?v=SCR9oSMCdOg
# ===================
#
# ===== 9번 box =====
# 영상제목 : [MV] IU(아이유) _ strawberry moon
# 조회수 :  2981만회
# 영상 게시일(현재날짜기준) : 9개월 전
# 채널명 : 1theK (원더케이)
# 영상 링크 : https://www.youtube.com//watch?v=sqgxcCjD04s
# ===================
#
# ===== 10번 box =====
# 영상제목 : 『Playlist』 2021 아이유 IU 노래모음ㅣBest Songs of IU ㅣ🎯『광고제거가능』
# 조회수 :  428만회
# 영상 게시일(현재날짜기준) : 1년 전
# 채널명 : 리스펙 뮤직 『Respect Music』
# 영상 링크 : https://www.youtube.com//watch?v=MwYq4vAH7bI
# ===================
#
# ===== 11번 box =====
# 영상제목 : IU (아이유) PLAYLIST 2022 UPDATED | 아이유 노래 모음
# 조회수 :  46만회
# 영상 게시일(현재날짜기준) : 7개월 전
# 채널명 : LQ KPOP
# 영상 링크 : https://www.youtube.com//watch?v=GrRbA6OkTxA
# ===================
#
# ===== 12번 box =====
# 영상제목 : [소장각👍 #68] 봄바람처럼♬ 내게 다가온 아이유..♥ 아직 보내줄 준비가 안 돼서 준비한 방구석 콘서트!🌸 [KBS 방송]
# 조회수 :  136만회
# 영상 게시일(현재날짜기준) : 1년 전
# 채널명 : KBS StarTV: 인물사전
# 영상 링크 : https://www.youtube.com//watch?v=63XUTCLOCnM
# ===================
#
# ===== 13번 box =====
# 영상제목 : [𝐅𝐮𝐥𝐥] 아이유 노래모음 | IU songs playlist
# 조회수 :  27만회
# 영상 게시일(현재날짜기준) : 8개월 전
# 채널명 : 스너그 ᴘʟᴀʏʟɪꜱᴛ
# 영상 링크 : https://www.youtube.com//watch?v=lKq7IdtGqXE
# ===================
#
# ===== 14번 box =====
# 영상제목 : 𝐏𝐥𝐚𝐲𝐥𝐢𝐬𝐭.  별빛 가득 움츠린 밤 나 혼자 듣고 싶은 아이유 발라드 모음
# 조회수 :  4.7만회
# 영상 게시일(현재날짜기준) : 6개월 전
# 채널명 : 쿼츠 𝐏𝐥𝐚𝐲𝐥𝐢𝐬𝐭
# 영상 링크 : https://www.youtube.com//watch?v=bDPjKiMSi_A
# ===================
#
# ===== 15번 box =====
# 영상제목 : [Playlist] 아이유의 목소리에 천천히 잠기는 깊은 밤.
# 조회수 :  373만회
# 영상 게시일(현재날짜기준) : 1년 전
# 채널명 : 짚이는 구석.
# 영상 링크 : https://www.youtube.com//watch?v=N75MHF7lMzo
# ===================
#
# ===== 16번 box =====
# 영상제목 : [IU TV] 어서와~ 드레스 피팅은 처음이지?
# 조회수 :  255만회
# 영상 게시일(현재날짜기준) : 2개월 전
# 채널명 : 이지금 [IU Official]
# 영상 링크 : https://www.youtube.com//watch?v=-1UXHfKnvCE
# ===================
#
# ===== 17번 box =====
# 영상제목 : [MV] IU(아이유) _ Blueming(블루밍)
# 조회수 :  1.4억회
# 영상 게시일(현재날짜기준) : 2년 전
# 채널명 : 1theK (원더케이)
# 영상 링크 : https://www.youtube.com//watch?v=D1PvIWdJ8xo
# ===================
#
# ===== 18번 box =====
# 영상제목 : [IU] '라일락' 응원법🔎 (Fanchants Guide)
# 조회수 :  79만회
# 영상 게시일(현재날짜기준) : 2주 전
# 채널명 : 이지금 [IU Official]
# 영상 링크 : https://www.youtube.com//watch?v=LqfimuFAFJ8
# ===================
#
# ===== 19번 box =====
# 영상제목 : [IU TV] Bonjour! 칸 영화제 vlog🎬
# 조회수 :  290만회
# 영상 게시일(현재날짜기준) : 1개월 전
# 채널명 : 이지금 [IU Official]
# 영상 링크 : https://www.youtube.com//watch?v=ekvJA3GZw1Y
# ===================
#
# ===== 20번 box =====
# 영상제목 : [MV] IU(아이유)_LILAC(라일락)
# 조회수 :  8624만회
# 영상 게시일(현재날짜기준) : 1년 전
# 채널명 : 1theK (원더케이)
# 영상 링크 : https://www.youtube.com//watch?v=v7bnOxV4jAc
# ===================
#
# ===== 21번 box =====
# 영상제목 : [정주행] 낮부터 밤까지 아이유 노래모음 50곡 | IU Playlist
# 조회수 :  45만회
# 영상 게시일(현재날짜기준) : 6개월 전
# 채널명 : 나의플레이리스트 ɴᴀᴘʟʏ
# 영상 링크 : https://www.youtube.com//watch?v=3FoJqr5pIS4
# ===================
#
# ===== 22번 box =====
# 영상제목 : 어게인 마이 라이프 시청률 10% 달성 기념! 이준기의 'That That - 싸이' 댄스 커버 영상! #어게인마이라이프 #AGAINMYLIFE ｜SBSNOW
# 조회수 :  84만회
# 영상 게시일(현재날짜기준) : 2개월 전
# 채널명 : SBS NOW / SBS 공식 채널
# 영상 링크 : https://www.youtube.com//watch?v=Tya03l9WAjo
# ===================
#
# ===== 23번 box =====
# 영상제목 : (ENG) 1️⃣건축학개론에서 작정하고 끼부렸다는 국민첫사랑 수지의 필살 멍멍스킬? 모니터 밝게 하고 보세요 웃는 내 모습에 놀랄 수 있음 / [문명특급 EP.253-1]
# 조회수 :  112만회
# 영상 게시일(현재날짜기준) : 1개월 전
# 채널명 : 문명특급 - MMTG
# 영상 링크 : https://www.youtube.com//watch?v=O_7Y3LESmr8
# ===================
#
# ===== 24번 box =====
# 영상제목 : Charlie Puth - Left And Right (feat. Jung Kook of BTS) [Official Video]
# 조회수 :  1.4억회
# 영상 게시일(현재날짜기준) : 1개월 전
# 채널명 : Charlie Puth
# 영상 링크 : https://www.youtube.com//watch?v=a7GITgqwDVg
# ===================
#
# ===== 25번 box =====
# 영상제목 : [아이유의 팔레트] 세븐틴이에유는 일촌이에유 (With 세븐틴) Ep.12
# 조회수 :  337만회
# 영상 게시일(현재날짜기준) : 2개월 전
# 채널명 : 이지금 [IU Official]
# 영상 링크 : https://www.youtube.com//watch?v=kUOIJ2OFxsY
# ===================
#
# ===== 26번 box =====
# 영상제목 : IU (아이유) Playlist | My Playlist IU 2022 UPDATED | 아이유 노래 모음
# 조회수 :  5.4만회
# 영상 게시일(현재날짜기준) : 1개월 전
# 채널명 : Random Avenue
# 영상 링크 : https://www.youtube.com//watch?v=xe1BzcoOYvQ
# ===================
#
# ===== 27번 box =====
# 영상제목 : 아이유 브이넥 어떤가요?
# 조회수 :  387만회
# 영상 게시일(현재날짜기준) : 6개월 전
# 채널명 : 금딸
# 영상 링크 : https://www.youtube.com//shorts/Xsva7IzNM6Y
# ===================
#
# ===== 28번 box =====
# 영상제목 : 아이유 - Love poem 가사 (러브 포엠) [Color Coded Lyrics/Han/Rom/Eng]
# 조회수 :  441만회
# 영상 게시일(현재날짜기준) : 2년 전
# 채널명 : Lemoring
# 영상 링크 : https://www.youtube.com//watch?v=A4jp4bH52E8
# ===================

# %%
import pandas as pd 
youtube_list_df = pd.DataFrame(data=youtube_list, columns=['영상제목', '조회수', '영상 게시일(현재날짜기준)', '채널명', '영상 링크'])

# %%
youtube_list_df
# Out:
#                                                  영상제목     조회수 영상 게시일(현재날짜기준)  \
# 0              아카데미 시상식 나온 한국배우가 1분간 침묵하며 보인 행동에 미국발칵   118만회          4개월 전
# 1                              BA 융합전공 윤호정 교수님 인터뷰 영상     27회          2개월 전
# 2                                  220506 깔롱 공연 (윤호정)    107회          2개월 전
# 3                        온새미로 뒷풀이ㅡ님의향기ㆍ윤호정 친구(원곡 김경남)    141회           2년 전
# 4                      윤호정 1983147 멀티미디어 디자인 중간고사 8주차      4회          7개월 전
# 5                 손석구 마동석 배두나 윤여정의 영어 연기를 "볼 수는 있습니다"    24만회           2년 전
# 6   윤여정 초대했다가 뻔한 대답이라곤 1도 없는 윤여정식 화법에 완전히 뒤집어진 미국토...   219만회          4개월 전
# 7                                     [정은채] 정은채 영어 모음    40만회           3년 전
# 8   [#인기급상승] '봉준호 거는 해야지!' 솔직 매력 끝판왕 윤여정 자기님💛 맞는 말...    88만회          4개월 전
# 9                                  짧은대본 이나 역 윤상정을 만났다    97만회           2년 전
# 10                                          코미팜 - 윤호정   1.6천회           9년 전
# 11                                 (윤호정 광고1화) 모두다LOVE     32회           6년 전
# 12                               호남대학교 정보통신공학과 윤호정 조!    141회          10년 전
# 13                2022-1학기 세종대 캠퍼스타운 | 지역연계수업 아카이빙 영상     52회           6일 전
# 14                                        성우하이텍 - 윤호정    193회          10년 전
#
#               채널명                                         영상 링크
# 0            단골이슈  https://www.youtube.com//watch?v=VvaxVwunlJg
# 1   세종대학교대학혁신지원사업  https://www.youtube.com//watch?v=noJ6oR1FHyM
# 2        큐티 성약20s  https://www.youtube.com//watch?v=sc0zELPWr5Q
# 3       뉴스헤드라인 TV  https://www.youtube.com//watch?v=OrdSNsiauhw
# 4              식이  https://www.youtube.com//watch?v=ZOeAspRPZNs
# 5         어퍼컷Tube  https://www.youtube.com//watch?v=7_l6Krd1hzY
# 6        원더WONDER  https://www.youtube.com//watch?v=2jzzos51N0s
# 7        같이 정긍채해요  https://www.youtube.com//watch?v=N8mziuQo8L0
# 8      디글 :Diggle  https://www.youtube.com//watch?v=o1L9E9ja_Qs
# 9    뉴슬러 Newstler  https://www.youtube.com//watch?v=SN43ECD2MO4
# 10    MTN 머니투데이방송  https://www.youtube.com//watch?v=qKTW6u7Xnew
# 11            윤호정  https://www.youtube.com//watch?v=qazmVQuJ5Tc
# 12           하이티어  https://www.youtube.com//watch?v=oTaucdLPSR8
# 13       세종대캠퍼스타운  https://www.youtube.com//watch?v=Aa91e3yeY1w
# 14    MTN 머니투데이방송  https://www.youtube.com//watch?v=7DZChU7G3xk

# %%
youtube_list_df.to_excel('유튜브 영상 정보 데이터(검색명 = {}).xlsx'.format(search_title))
print('{} 검색 결과 영상 정보 데이터셋 저장완료'.format(search_title))
# Out:
# 세종대학교 검색 결과 영상 정보 데이터셋 저장완료
